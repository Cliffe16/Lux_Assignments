# %%
import http.client

conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': "apikey 3OvouOHfeNzVEdGesGWhIN:2AIeVbzzsVuNkfwG7VzTGR"
    }

conn.request("GET", "/gasPrice/stateUsaPrice?state=WA", headers=headers)

res = conn.getresponse()
data = res.read()
data = data.decode("utf-8")

data
# Out:
# '{"success":false,"code":500,"message":"You do not have any subscription to this api."}'

# %%
type(data)
# Out:
# str

# %%
import json
data = json.loads(data.to_json(orient="records"))
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 2
#       1 import json
# ----> 2 data = json.loads(data.to_json(orient="records"))
#       3 data
#
# AttributeError: 'str' object has no attribute 'to_json'

# %%
type(data)

# %%
data = js
