# %%
# !pip install massive
from massive import RESTClient

client = RESTClient("lppjfqABG22zKmPuspOyep56wMdB0772")

tickers = []
for t in client.list_tickers(
	type="FUND",
	market="stocks",
	active="true",
	order="asc",
	limit="100",
	sort="ticker",
	):
    tickers.append(t)

print(tickers)
# Out:
# Requirement already satisfied: massive in /home/cliffe/anaconda3/lib/python3.12/site-packages (2.5.0)
# Requirement already satisfied: certifi<2027.0.0,>=2022.5.18 in /home/cliffe/anaconda3/lib/python3.12/site-packages (from massive) (2024.8.30)
# Requirement already satisfied: urllib3>=1.26.9 in /home/cliffe/anaconda3/lib/python3.12/site-packages (from massive) (2.2.3)
# Requirement already satisfied: websockets>=14.0 in /home/cliffe/anaconda3/lib/python3.12/site-packages (from massive) (16.0)
# [Ticker(active=True, cik='0001503290', composite_figi='BBG0017VSC04', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986203257Z', locale='us', market='stocks', name='abrdn Income Credit Strategies Fund', primary_exchange='XNYS', share_class_figi='BBG001TCSLH4', ticker='ACP', type='FUND', source_feed=None), Ticker(active=True, cik='0001636289', composite_figi='BBG008HMBD22', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986205341Z', locale='us', market='stocks', name='Virtus Diversified Income & Convertible Fund', primary_exchange='XNYS', share_class_figi='BBG008HMBD31', ticker='ACV', type='FUND', source_feed=None), Ticker(active=True, cik='0000002230', composite_figi='BBG000BB8MR6', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986211783Z', locale='us', market='stocks', name='Adams Diversified Equity Fund, Inc', primary_exchange='XNYS', share_class_figi='BBG001S5NDV7', ticker='ADX', type='FUND', source_feed=None), Ticker(active=True, cik='0000846676', composite_figi='BBG000BGWCV5', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986212805Z', locale='us', market='stocks', name='abrdn Emerging Markets ex-China Fund, Inc.', primary_exchange='XASE', share_class_figi='BBG001S5QCR1', ticker='AEF', type='FUND', source_feed=None), Ticker(active=True, cik='0001162027', composite_figi='BBG000DTM676', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986215551Z', locale='us', market='stocks', name='Alliance National Municipal Income Fund, Inc.', primary_exchange='XNYS', share_class_figi='BBG001SK6452', ticker='AFB', type='FUND', source_feed=None), Ticker(active=True, cik='0001362481', composite_figi='BBG000DJLNL6', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986219278Z', locale='us', market='stocks', name='abrdn Global Dynamic Dividend Fund', primary_exchange='XNYS', share_class_figi='BBG001SMLZ16', ticker='AGD', type='FUND', source_feed=None), Ticker(active=True, cik='0001778114', composite_figi='BBG00Q7474K8', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986229718Z', locale='us', market='stocks', name='Virtus Artificial Intelligence & Technology Opportunities Fund', primary_exchange='XNYS', share_class_figi='BBG00Q7474L7', ticker='AIO', type='FUND', source_feed=None), Ticker(active=True, cik='0001379400', composite_figi='BBG000QC34R3', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986262661Z', locale='us', market='stocks', name='abrdn Total Dynamic Dividend Fund', primary_exchange='XNYS', share_class_figi='BBG001SS0YX4', ticker='AOD', type='FUND', source_feed=None), Ticker(active=True, cik='0001515324', composite_figi='BBG001LJH325', currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.986275195Z', locale='us', market='stocks', name='ARES DYNAMIC CREDIT ALLOCATION FUND, INC.', primary_exchange='XNYS', share_class_figi='BBG001V0WD35', ticker='ARDC', type='FUND', source_feed=None), Ticker(active=True, cik='0001230869', composite_figi=None, currency_name='usd', currency_symbol=None, base_currency_symbol=None, base_currency_name=None, delisted_utc=None, last_updated_utc='2026-04-22T06:09:41.98628317Z', locale='us', ...

# %%
type(tickers)
# Out:
# list

# %%
import pandas as pd
df = pd.DataFrame(tickers)
df
# Out:
#      active         cik composite_figi currency_name currency_symbol  \
# 0      True  0001503290   BBG0017VSC04           usd            None
# 1      True  0001636289   BBG008HMBD22           usd            None
# 2      True  0000002230   BBG000BB8MR6           usd            None
# 3      True  0000846676   BBG000BGWCV5           usd            None
# 4      True  0001162027   BBG000DTM676           usd            None
# ..      ...         ...            ...           ...             ...
# 336    True  0001163792   BBG000BPYDK3           usd            None
# 337    True  0001254370   BBG000BRVNL9           usd            None
# 338    True  0001267902   BBG000BSK789           usd            None
# 339    True  0001703079   BBG00HMS4SC7           usd            None
# 340    True  0000836412   BBG000BXB8X8           usd            None
#
#     base_currency_symbol base_currency_name delisted_utc  \
# 0                   None               None         None
# 1                   None               None         None
# 2                   None               None         None
# 3                   None               None         None
# 4                   None               None         None
# ..                   ...                ...          ...
# 336                 None               None         None
# 337                 None               None         None
# 338                 None               None         None
# 339                 None               None         None
# 340                 None               None         None
#
#                    last_updated_utc locale  market  \
# 0    2026-04-22T06:09:41.986203257Z     us  stocks
# 1    2026-04-22T06:09:41.986205341Z     us  stocks
# 2    2026-04-22T06:09:41.986211783Z     us  stocks
# 3    2026-04-22T06:09:41.986212805Z     us  stocks
# 4    2026-04-22T06:09:41.986215551Z     us  stocks
# ..                              ...    ...     ...
# 336  2026-04-22T06:09:41.987822442Z     us  stocks
# 337  2026-04-22T06:09:41.987829315Z     us  stocks
# 338  2026-04-22T06:09:41.987830828Z     us  stocks
# 339  2026-04-22T06:09:41.987855465Z     us  stocks
# 340  2026-04-22T06:09:41.987903327Z     us  stocks
#
#                                                   name primary_exchange  \
# 0                  abrdn Income Credit Strategies Fund             XNYS
# 1         Virtus Diversified Income & Convertible Fund             XNYS
# 2                   Adams Diversified Equity Fund, Inc             XNYS
# 3           abrdn Emerging Markets ex-China Fund, Inc.             XASE
# 4        Alliance National Municipal Income Fund, Inc.             XNYS
# ..                                                 ...              ...
# 336                    Western Asset Premier Bond Fund             XNYS
# 337         Western Asset Inflation-Linked Income Fund             XNYS
# 338  Western Asset Inflation-Linked Opportunities &...             XNYS
# 339  XAI Octagon Floating Rate and Alternative Inco...             XNYS
# 340                      Virtus Total Return Fund Inc.             XNYS
#
#     share_class_figi ticker  type source_feed
# 0       BBG001TCSLH4    ACP  FUND        None
# 1       BBG008HMBD31    ACV  FUND        None
# 2       BBG001S5NDV7    ADX  FUND        None
# 3       BBG001S5QCR1    AEF  FUND        None
# 4       BBG001SK6452    AFB  FUND        None
# ..               ...    ...   ...         ...
# 336     BBG001SB94R5    WEA  FUND        None
# 337     BBG001SBSMH5    WIA  FUND        None
# 338     BBG001SBWXC1    WIW  FUND        None
# 339     BBG00HMS4SD6   XFLT  FUND        None
# 340     BBG001S5XNL5    ZTR  FUND        None
#
# [341 rows x 17 columns]

# %%
df.count()
# Out:
# active                  341
# cik                     341
# composite_figi          340
# currency_name           341
# currency_symbol           0
# base_currency_symbol      0
# base_currency_name        0
# delisted_utc              0
# last_updated_utc        341
# locale                  341
# market                  341
# name                    341
# primary_exchange        341
# share_class_figi        340
# ticker                  341
# type                    341
# source_feed               0
# dtype: int64

# %%
df.drop(['currency_symbol', 'base_currency_symbol', 'base_currency_name', 'delisted_utc', 'source_feed'], axis=1,inplace=True)
df
# Out:
#      active         cik composite_figi currency_name  \
# 0      True  0001503290   BBG0017VSC04           usd
# 1      True  0001636289   BBG008HMBD22           usd
# 2      True  0000002230   BBG000BB8MR6           usd
# 3      True  0000846676   BBG000BGWCV5           usd
# 4      True  0001162027   BBG000DTM676           usd
# ..      ...         ...            ...           ...
# 336    True  0001163792   BBG000BPYDK3           usd
# 337    True  0001254370   BBG000BRVNL9           usd
# 338    True  0001267902   BBG000BSK789           usd
# 339    True  0001703079   BBG00HMS4SC7           usd
# 340    True  0000836412   BBG000BXB8X8           usd
#
#                    last_updated_utc locale  market  \
# 0    2026-04-22T06:09:41.986203257Z     us  stocks
# 1    2026-04-22T06:09:41.986205341Z     us  stocks
# 2    2026-04-22T06:09:41.986211783Z     us  stocks
# 3    2026-04-22T06:09:41.986212805Z     us  stocks
# 4    2026-04-22T06:09:41.986215551Z     us  stocks
# ..                              ...    ...     ...
# 336  2026-04-22T06:09:41.987822442Z     us  stocks
# 337  2026-04-22T06:09:41.987829315Z     us  stocks
# 338  2026-04-22T06:09:41.987830828Z     us  stocks
# 339  2026-04-22T06:09:41.987855465Z     us  stocks
# 340  2026-04-22T06:09:41.987903327Z     us  stocks
#
#                                                   name primary_exchange  \
# 0                  abrdn Income Credit Strategies Fund             XNYS
# 1         Virtus Diversified Income & Convertible Fund             XNYS
# 2                   Adams Diversified Equity Fund, Inc             XNYS
# 3           abrdn Emerging Markets ex-China Fund, Inc.             XASE
# 4        Alliance National Municipal Income Fund, Inc.             XNYS
# ..                                                 ...              ...
# 336                    Western Asset Premier Bond Fund             XNYS
# 337         Western Asset Inflation-Linked Income Fund             XNYS
# 338  Western Asset Inflation-Linked Opportunities &...             XNYS
# 339  XAI Octagon Floating Rate and Alternative Inco...             XNYS
# 340                      Virtus Total Return Fund Inc.             XNYS
#
#     share_class_figi ticker  type
# 0       BBG001TCSLH4    ACP  FUND
# 1       BBG008HMBD31    ACV  FUND
# 2       BBG001S5NDV7    ADX  FUND
# 3       BBG001S5QCR1    AEF  FUND
# 4       BBG001SK6452    AFB  FUND
# ..               ...    ...   ...
# 336     BBG001SB94R5    WEA  FUND
# 337     BBG001SBSMH5    WIA  FUND
# 338     BBG001SBWXC1    WIW  FUND
# 339     BBG00HMS4SD6   XFLT  FUND
# 340     BBG001S5XNL5    ZTR  FUND
#
# [341 rows x 12 columns]

# %%
from massive import RESTClient

client = RESTClient("lppjfqABG22zKmPuspOyep56wMdB0772")

companies = ["AAPL", "GOOG", "TSLA", "AMZN", "NFLX"]
data = []

for ticker in companies:
    request = client.get_daily_open_close_agg(
        ticker,
        "2025-04-22",
        adjusted="true",
    )
    data.append(request)
data
# Out:
# [DailyOpenCloseAgg(after_hours=205, close=199.74, from_='2025-04-22', high=201.59, low=195.97, open=196.12, pre_market=193.79, status='OK', symbol='AAPL', volume=52976371.0, otc=None),
#  DailyOpenCloseAgg(after_hours=157.05, close=153.9, from_='2025-04-22', high=154.61, low=150.87, open=151.07, pre_market=151.36, status='OK', symbol='GOOG', volume=15910327.0, otc=None),
#  DailyOpenCloseAgg(after_hours=250.8, close=237.97, from_='2025-04-22', high=242.79, low=229.8501, open=230.96, pre_market=230.24, status='OK', symbol='TSLA', volume=120858452.0, otc=None),
#  DailyOpenCloseAgg(after_hours=179.82, close=173.18, from_='2025-04-22', high=176.78, low=169.35, open=169.845, pre_market=169.29, status='OK', symbol='AMZN', volume=56607202.0, otc=None),
#  DailyOpenCloseAgg(after_hours=105.343, close=104.034, from_='2025-04-22', high=106.497, low=100.452, open=100.53, pre_market=99.3, status='OK', symbol='NFLX', volume=93688730.0, otc=None)]

# %%
type(data)
# Out:
# list

# %%
df = pd.DataFrame(data)
df_json = json.loads(df.to_json(orient="records"))
df_json
# Out:
# [{'after_hours': 205.0,
#   'close': 199.74,
#   'from_': '2025-04-22',
#   'high': 201.59,
#   'low': 195.97,
#   'open': 196.12,
#   'pre_market': 193.79,
#   'status': 'OK',
#   'symbol': 'AAPL',
#   'volume': 52976371.0,
#   'otc': None},
#  {'after_hours': 157.05,
#   'close': 153.9,
#   'from_': '2025-04-22',
#   'high': 154.61,
#   'low': 150.87,
#   'open': 151.07,
#   'pre_market': 151.36,
#   'status': 'OK',
#   'symbol': 'GOOG',
#   'volume': 15910327.0,
#   'otc': None},
#  {'after_hours': 250.8,
#   'close': 237.97,
#   'from_': '2025-04-22',
#   'high': 242.79,
#   'low': 229.8501,
#   'open': 230.96,
#   'pre_market': 230.24,
#   'status': 'OK',
#   'symbol': 'TSLA',
#   'volume': 120858452.0,
#   'otc': None},
#  {'after_hours': 179.82,
#   'close': 173.18,
#   'from_': '2025-04-22',
#   'high': 176.78,
#   'low': 169.35,
#   'open': 169.845,
#   'pre_market': 169.29,
#   'status': 'OK',
#   'symbol': 'AMZN',
#   'volume': 56607202.0,
#   'otc': None},
#  {'after_hours': 105.343,
#   'close': 104.034,
#   'from_': '2025-04-22',
#   'high': 106.497,
#   'low': 100.452,
#   'open': 100.53,
#   'pre_market': 99.3,
#   'status': 'OK',
#   'symbol': 'NFLX',
#   'volume': 93688730.0,
#   'otc': None}]

# %%
df_transform = pd.DataFrame(df_json)
df_transform
# Out:
#    after_hours    close       from_     high       low     open  pre_market  \
# 0      205.000  199.740  2025-04-22  201.590  195.9700  196.120      193.79
# 1      157.050  153.900  2025-04-22  154.610  150.8700  151.070      151.36
# 2      250.800  237.970  2025-04-22  242.790  229.8501  230.960      230.24
# 3      179.820  173.180  2025-04-22  176.780  169.3500  169.845      169.29
# 4      105.343  104.034  2025-04-22  106.497  100.4520  100.530       99.30
#
#   status symbol       volume   otc
# 0     OK   AAPL   52976371.0  None
# 1     OK   GOOG   15910327.0  None
# 2     OK   TSLA  120858452.0  None
# 3     OK   AMZN   56607202.0  None
# 4     OK   NFLX   93688730.0  None

# %%
df_transform = df_transform.rename(columns={"from_": "date"})
df_transform = df_transform.drop(["otc"], axis=1)
df_transform["price change"] = df_transform["close"] - df_transform["open"]
df_transform
# Out:
#    after_hours    close        date     high       low     open  pre_market  \
# 0      205.000  199.740  2025-04-22  201.590  195.9700  196.120      193.79
# 1      157.050  153.900  2025-04-22  154.610  150.8700  151.070      151.36
# 2      250.800  237.970  2025-04-22  242.790  229.8501  230.960      230.24
# 3      179.820  173.180  2025-04-22  176.780  169.3500  169.845      169.29
# 4      105.343  104.034  2025-04-22  106.497  100.4520  100.530       99.30
#
#   status symbol       volume  price change
# 0     OK   AAPL   52976371.0         3.620
# 1     OK   GOOG   15910327.0         2.830
# 2     OK   TSLA  120858452.0         7.010
# 3     OK   AMZN   56607202.0         3.335
# 4     OK   NFLX   93688730.0         3.504
